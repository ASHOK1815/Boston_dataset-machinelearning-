# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn.datasets import load_boston
boston=load_boston()

# %%
boston_df=pd.DataFrame(boston["data"],columns=boston["feature_names"])
boston_df["target"]=pd.Series(boston["target"])
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
np.random.seed(42);

x=boston_df.drop("target",axis=1)
y=boston_df["target"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=Ridge()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.6662221670168519

# %% [markdown]
# ## Now we have to improve the score part...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
np.random.seed(42)

# %%
x_ran=boston_df.drop("target",axis=1)
y_ran=boston_df["target"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x_ran,y_ran,test_size=0.2)

# %%
model1=RandomForestRegressor(n_estimators=100)

# %%
model1.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
# this is the score of the RandomForestRegressor
model1.score(x_test,y_test)
# Out:
# 0.873969014117403

# %%
#Now lets show the score of samedataset using Ridge
model.score(x_test,y_test)
# Out:
# 0.6662221670168519

# %% [markdown]
# ### lets make some predictions also

# %%
y_preds=model1.predict(x_test)

# %%
y_preds[:10]
# Out:
# array([23.002, 30.826, 16.734, 23.467, 16.853, 21.725, 19.232, 15.239,
#        21.067, 20.738])

# %%
np.array(y_test[:10])
# Out:
# array([23.6, 32.4, 13.6, 22.8, 16.1, 20. , 17.8, 14. , 19.6, 16.8])

# %% [markdown]
# ## Regression model evaluation metrics

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
np.random.seed(42)

x=boston_df.drop("target",axis=1)
y=boston_df["target"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=RandomForestRegressor(n_estimators=100)
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.8761465016965136

# %%
from sklearn.metrics import r2_score

# %%
y_test_mean=np.full(len(y_test),y_test.mean())

# %%
y_test.mean()
# Out:
# 21.488235294117654

# %%
r2_score(y_test,y_test_mean)
# Out:
# 2.220446049250313e-16

# %% [markdown]
# ### Mean Absoluter Error

# %%
from sklearn.metrics import  mean_absolute_error
pd.set_option("display.max_columns",3)
pd.set_option("display.max_rows",102)

# %%
y_preds=model.predict(x_test)

# %%
mae=mean_absolute_error(y_test ,y_preds)

# %%
mae
# Out:
# 2.116078431372549

# %%
df=pd.DataFrame(data={"Actual_Values" : y_test,
                   "Predicited_Values" :y_preds})

df["Difference"]=df["Actual_Values"]-df["Predicited_Values"]

# %%
df
# Out:
#      Actual_Values  Predicited_Values  Difference
# 173           23.6             22.992       0.608
# 274           32.4             30.267       2.133
# 491           13.6             16.572      -2.972
# 72            22.8             23.413      -0.613
# 452           16.1             17.086      -0.986
# 76            20.0             21.784      -1.784
# 316           17.8             19.750      -1.950
# 140           14.0             15.264      -1.264
# 471           19.6             21.109      -1.509
# 500           16.8             20.496      -3.696
# 218           21.5             19.541       1.959
# 9             18.9             19.842      -0.942
# 414            7.0              8.649      -1.649
# 78            21.2             21.744      -0.544
# 323           18.5             19.574      -1.074
# 473           29.8             26.267       3.533
# 124           18.8             18.953      -0.153
# 388           10.2              8.168       2.032
# 195           50.0             45.887       4.113
# 448           14.1             15.011      -0.911
# 271           25.2             24.521       0.679
# 278           29.1             24.002       5.098
# 30            12.7             14.690      -1.990
# 501           22.4             23.608      -1.208
# 421           14.2             14.970      -0.770
# 474           13.8             14.731      -0.931
# 79            20.3             21.143      -0.843
# 454           14.9             14.033       0.867
# 210           21.7             19.251       2.449
# 497           18.3             20.839      -2.539
# 172           23.1             19.857       3.243
# 320           23.8             23.218       0.582
# 375           15.0             30.751     -15.751
# 362           20.8             20.026       0.774
# 467           19.1             14.132       4.968
# 153           19.4             16.002       3.398
# 2             34.7             34.462       0.238
# 336           19.5             19.208       0.292
# 208           24.4             20.795       3.605
# 73            23.4             24.321      -0.921
# 496           19.7             18.894       0.806
# 307           28.2             29.867      -1.667
# 204           50.0             45.663       4.337
# 68            17.4             19.496      -2.096
# 90            22.6             22.319       0.281
# 390           15.1             13.745       1.355
# 33            13.1             15.477      -2.377
# 70            24.2             24.480      -0.280
# 470           19.9             19.095       0.805
# 0             24.0             28.282      -4.282
# 11            18.9             21.453      -2.553
# 281           35.4             33.905       1.495
# 22            15.2             16.949      -1.749
# 101           26.5             26.328       0.172
# 268           43.5             44.704      -1.204
# 485           21.2             22.023      -0.823
# 442           18.4             15.505       2.895
# 290           28.5             32.361      -3.861
# 84            23.9             22.213       1.687
# 245           18.5             20.675      -2.175
# 63            25.0             25.309      -0.309
# 55            35.4             34.190       1.210
# 229           31.5             28.620       2.880
# 18            20.2             18.635       1.565
# 351           24.1             26.980      -2.880
# 209           20.0             17.134       2.866
# 395           13.1             13.796      -0.696
# 82            24.8             23.203       1.597
# 39            30.8             28.441       2.359
# 456           12.7             15.250      -2.550
# 46            20.0             20.300      -0.300
# 481           23.7             28.622      -4.922
# 444           10.8             10.390       0.410
# 355           20.6             21.018      -0.418
# 77            20.8             22.184      -1.384
# 398            5.0              7.056      -2.056
# 104           20.1             20.139      -0.039
# 203           48.5             45.871       2.629
# 381           10.9             10.862       0.038
# 489            7.0             12.987      -5.987
# 69            20.9             21.439      -0.539
# 408           17.2             12.350       4.850
# 255           20.9             20.087       0.813
# 392            9.7              9.101       0.599
# 312           19.4             20.258      -0.858
# 234           29.0             26.610       2.390
# 460           16.4             15.470       0.930
# 324           25.0             23.292       1.708
# 93            25.0             23.621       1.379
# 137           17.1             17.727      -0.627
# 176           23.2             21.599       1.601
# 417           10.4              8.034       2.366
# 131           19.6             19.462       0.138
# 346           17.2             18.985      -1.785
# 365           27.5             22.258       5.242
# 132           23.0             19.361       3.639
# 371           50.0             38.696      11.304
# 412           17.9             12.948       4.952
# 436            9.6             12.266      -2.666
# 411           17.2             13.620       3.580
# 86            22.5             20.249       2.251
# 75            21.4             23.457      -2.057

# %% [markdown]
# ### Mean Squared Error

# %%
from sklearn.metrics import mean_squared_error

y_preds=model.predict(x_test)
np.random.seed(42)
mse=mean_squared_error(y_test,y_preds)

# %%
mse
# Out:
# 9.082645588235298

# %%
df1=pd.DataFrame(data={"Actual_Values" : y_test,
                   "Predicited_Values" :y_preds})

# %%
df1
# Out:
#      Actual_Values  Predicited_Values
# 173           23.6             22.992
# 274           32.4             30.267
# 491           13.6             16.572
# 72            22.8             23.413
# 452           16.1             17.086
# 76            20.0             21.784
# 316           17.8             19.750
# 140           14.0             15.264
# 471           19.6             21.109
# 500           16.8             20.496
# 218           21.5             19.541
# 9             18.9             19.842
# 414            7.0              8.649
# 78            21.2             21.744
# 323           18.5             19.574
# 473           29.8             26.267
# 124           18.8             18.953
# 388           10.2              8.168
# 195           50.0             45.887
# 448           14.1             15.011
# 271           25.2             24.521
# 278           29.1             24.002
# 30            12.7             14.690
# 501           22.4             23.608
# 421           14.2             14.970
# 474           13.8             14.731
# 79            20.3             21.143
# 454           14.9             14.033
# 210           21.7             19.251
# 497           18.3             20.839
# 172           23.1             19.857
# 320           23.8             23.218
# 375           15.0             30.751
# 362           20.8             20.026
# 467           19.1             14.132
# 153           19.4             16.002
# 2             34.7             34.462
# 336           19.5             19.208
# 208           24.4             20.795
# 73            23.4             24.321
# 496           19.7             18.894
# 307           28.2             29.867
# 204           50.0             45.663
# 68            17.4             19.496
# 90            22.6             22.319
# 390           15.1             13.745
# 33            13.1             15.477
# 70            24.2             24.480
# 470           19.9             19.095
# 0             24.0             28.282
# 11            18.9             21.453
# 281           35.4             33.905
# 22            15.2             16.949
# 101           26.5             26.328
# 268           43.5             44.704
# 485           21.2             22.023
# 442           18.4             15.505
# 290           28.5             32.361
# 84            23.9             22.213
# 245           18.5             20.675
# 63            25.0             25.309
# 55            35.4             34.190
# 229           31.5             28.620
# 18            20.2             18.635
# 351           24.1             26.980
# 209           20.0             17.134
# 395           13.1             13.796
# 82            24.8             23.203
# 39            30.8             28.441
# 456           12.7             15.250
# 46            20.0             20.300
# 481           23.7             28.622
# 444           10.8             10.390
# 355           20.6             21.018
# 77            20.8             22.184
# 398            5.0              7.056
# 104           20.1             20.139
# 203           48.5             45.871
# 381           10.9             10.862
# 489            7.0             12.987
# 69            20.9             21.439
# 408           17.2             12.350
# 255           20.9             20.087
# 392            9.7              9.101
# 312           19.4             20.258
# 234           29.0             26.610
# 460           16.4             15.470
# 324           25.0             23.292
# 93            25.0             23.621
# 137           17.1             17.727
# 176           23.2             21.599
# 417           10.4              8.034
# 131           19.6             19.462
# 346           17.2             18.985
# 365           27.5             22.258
# 132           23.0             19.361
# 371           50.0             38.696
# 412           17.9             12.948
# 436            9.6             12.266
# 411           17.2             13.620
# 86            22.5             20.249
# 75            21.4             23.457
